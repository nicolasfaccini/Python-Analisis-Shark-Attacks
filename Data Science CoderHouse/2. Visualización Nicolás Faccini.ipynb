# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Shark Attacks Dataset

# %% [markdown]
# ## Introducción, Variables y Posibilidades

# %%
from IPython.display import Image

Image("/content/drive/MyDrive/Data Science CoderHouse/Datasets + IMG + Docu/tiburon.jpg")

# %% [markdown]
# Este dataset registra los ataques de tiburones reportados en los últimos 100 años, incluyendo información sobre la ubicación, actividad, datos de las víctimas (nombre, género, edad), especies de tiburones, entre otros. Estos datos ofrecen la posibilidad de analizar tendencias, identificar factores de riesgo y intentar predecir futuras localizaciones o fechas de ataques (si los datos lo permiten).
#
# El dataset cubre un período de 100 años, lo que proporciona una gran cantidad de datos históricos sobre ataques de tiburones. Se podrian realizar análisis de tendencias y patrones a lo largo del tiempo, ya que incluye características como la fecha, ubicación, actividad de la persona, especie de tiburón, entre otros.
#
# Ademas, los ataques de tiburones son eventos de interés público, y muchas personas tienen pánico a los mismos. El análisis de este dataset puede proporcionar información valiosa para comprender mejor estos incidentes, evaluar riesgos y apoyar la toma de decisiones en áreas como la seguridad acuática y la conservación marina, y tratar de entender si es justificado o no el miedo a este desafortunado evento, teniendo en cuenta la cantidad y distribucion de los ataques y las posibildades de muerte.
#
# Para resumir, este dataset ofrece una oportunidad interesante para aplicar técnicas de Data Science y machine learning, explorando las características de los ataques de tiburones a lo largo del tiempo y construyendo modelos predictivos para abordar cuestiones relacionadas con la seguridad y la conservación.
#
#
# --------------------------------------------------------------------------------
#
#
# A continuacion, cada titulo de columna y una breve descripcion aproximada, ya que la pagina de donde se obtiene el dataset no aclara.
#
# 'Case Number': Número de caso del ataque de tiburón.
#
# 'Date': Fecha del incidente del ataque de tiburón.
#
# 'Year': Año del incidente del ataque de tiburón.
#
# 'Type': Tipo de incidente del ataque de tiburón, como "Provoked" (Provocado) o "Unprovoked" (No provocado).
#
# 'Country': País donde ocurrió el ataque de tiburón.
#
# 'Area': Área geográfica específica dentro del país donde ocurrió el ataque de tiburón.
#
# 'Location': Ubicación más precisa del incidente del ataque de tiburón.
#
# 'Activity': Actividad que estaba realizando la persona en el momento del ataque.
#
# 'Name': Nombre de la persona involucrada en el ataque.
#
# 'Sex': Género de la persona involucrada en el ataque (masculino o femenino).
#
# 'Age': Edad de la persona involucrada en el ataque.
#
# 'Injury': Descripción de las lesiones sufridas por la persona durante el ataque de tiburón.
#
# 'Fatal (Y/N)': Indicador si el ataque de tiburón fue fatal o no (Sí o No).
#
# 'Time': Hora del día en que ocurrió el ataque de tiburón.
#
# 'Species': Especie de tiburón involucrada en el ataque, si se conoce.
#
# 'Investigator or Source': Investigador o fuente de la información sobre el ataque de tiburón.
#
# 'pdf': Nombre del archivo PDF relacionado con el caso de ataque de tiburón.
#
# 'href formula': Fórmula para construir el enlace del caso de ataque de tiburón.
#
# 'href': Enlace al caso de ataque de tiburón.
#
# 'Case Number.1': Número de caso adicional relacionado con el ataque de tiburón.
#
# 'Case Number.2': Otro número de caso adicional relacionado con el ataque de tiburón.
#
# 'original order': Orden original del caso de ataque de tiburón en el dataset.
#
# Links revisados: https://www.mavenanalytics.io/data-playground?search=shark // https://data.world/shruti-prabhu/shark-attacks

# %%
path = "/content/drive/MyDrive/Data Science CoderHouse/Datasets + IMG + Docu/Shark attacks.csv"
df1 = pd.read_csv(path, encoding='latin1')

# %%
df2 = df1.iloc[0:6094]
df2
# Out:
#        Case Number                  Date    Year        Type  \
# 0       2017.06.11            2017-06-11  2017.0  Unprovoked
# 1     2017.06.10.b            2017-06-10  2017.0  Unprovoked
# 2     2017.06.10.a            2017-06-10  2017.0  Unprovoked
# 3     2017.06.07.R  Reported 07-Jun-2017  2017.0  Unprovoked
# 4       2017.06.04            2017-06-04  2017.0  Unprovoked
# ...            ...                   ...     ...         ...
# 6089       ND.0005           Before 1903     0.0  Unprovoked
# 6090       ND.0004           Before 1903     0.0  Unprovoked
# 6091       ND.0003             1900-1905     0.0  Unprovoked
# 6092       ND.0002             1883-1889     0.0  Unprovoked
# 6093       ND.0001             1845-1853     0.0  Unprovoked
#
#                  Country               Area  \
# 0              AUSTRALIA  Western Australia
# 1              AUSTRALIA           Victoria
# 2                    USA            Florida
# 3         UNITED KINGDOM        South Devon
# ...

# %%
df2.shape
# Out:
# (6094, 22)

# %%
print(f'Cantidad de Registros: {df2.shape[0]}')
print(f'Cantidad de Columnas: {df2.shape[1]}')
# Out:
# Cantidad de Registros: 6094
# Cantidad de Columnas: 22

# %%
#Listado de Columnas
df2.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6094 entries, 0 to 6093
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6094 non-null   object
#  1   Date                    6094 non-null   object
#  2   Year                    6092 non-null   float64
#  3   Type                    6090 non-null   object
#  4   Country                 6048 non-null   object
#  5   Area                    5682 non-null   object
#  6   Location                5583 non-null   object
#  7   Activity                5559 non-null   object
#  8   Name                    5888 non-null   object
#  9   Sex                     5517 non-null   object
#  10  Age                     3374 non-null   object
#  11  Injury                  6066 non-null   object
#  12  Fatal (Y/N)             6064 non-null   object
#  13  Time                    2848 non-null   object
# ...

# %%
df2.head().T
# Out:
#                                                                         0  \
# Case Number                                                    2017.06.11
# Date                                                           2017-06-11
# Year                                                               2017.0
# Type                                                           Unprovoked
# Country                                                         AUSTRALIA
# Area                                                    Western Australia
# Location                                         Point Casuarina, Bunbury
# Activity                                                    Body boarding
# Name                                                            Paul Goff
# Sex                                                                     M
# Age                                                                    48
# Injury                                            No injury, board bitten
# ...

# %%
##este grafico me quedo mal, no me gusto
##pase edad y año a "numeric" (int)

df2['Year'] = pd.to_numeric(df2['Year'], errors='coerce')
df2['Age'] = pd.to_numeric(df2['Age'], errors='coerce')

plt.plot(df2['Year'], df2['Age'])
plt.xlabel('Año del incidente')
plt.ylabel('Edad de la persona')
plt.title('Relación entre año del incidente y edad')
plt.show()
# Out:
# <ipython-input-11-48c2a978916b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Year'] = pd.to_numeric(df2['Year'], errors='coerce')
# <ipython-input-11-48c2a978916b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Age'] = pd.to_numeric(df2['Age'], errors='coerce')

# %% [markdown]
# este grafico es un poco confuso, pero al parecer la edad no es un factor tan importante al momento de ser atacado por tiburones. creo que podria ser un poco mas claro, o podriamos usar unicamente años del 1750 en adelante y que tenga un poco mas de detalle.

# %%
sns.histplot(df2['Age'], kde=True)
plt.xlabel('Edad de la persona')
plt.ylabel('Frecuencia')
plt.title('Distribución de edades')
plt.show()
print(df2['Age'].describe())
# Out:
# count    3272.000000
# mean       27.297677
# std        13.832669
# min         1.000000
# 25%        17.000000
# 50%        24.000000
# 75%        35.000000
# max        87.000000
# Name: Age, dtype: float64

# %% [markdown]
# este grafico es muchisimo mas claro que el anterior, y sacamos la cuestion de los años, por lo que es mas facil ver las edades. Al parecer, alrededor de los 20 años es el momento en el que hay mas ataques de tiburones. se podria cruzar esta informacion con las actividades que estaban realizando a ver si hay alguna relacion, pero en cuadros de mas abajo vemos que la actividad que mas ataques sufre es el surf, y talvez es una actividad que realizan adolescentes. tendriamos que indagar un poco mas.

# %%
sns.boxplot(x='Type', y='Age', data=df2)
plt.xlabel('Tipo de incidente')
plt.ylabel('Edad de la persona')
plt.title('Distribución de edades por tipo de incidente')
plt.show()

# %%
df2['Type'].value_counts()
# Out:
# Unprovoked      4466
# Provoked         563
# Invalid          529
# Sea Disaster     220
# Boat             202
# Boating          110
# Name: Type, dtype: int64

# %% [markdown]
# Este grafico me parece que no es muy util, esta muy confuso ya que no muestra cuantos fueron provocados y cuantos no. Tampoco aclara el dataset que signfiica "invalid", y ademas incluye sea disaster, boat y boating, que deberian ir en actividad en vez de en provoked/unprovoked.
#
# Igualmente, vemos que la mayoria de casos (con ayuda del value_counts) son no provocados, y vemos que la edad esta concentrada entre los 20 y 30, digamos. Sin embargo, vemos que es la categoria con mas outliers.

# %%
df2 = df2[df2['Year'] >= 1700] ## para que solo agarre del 1700 en adelante

attacks_per_year = df2.groupby('Year').size()


plt.figure(figsize=(12,6))
sns.lineplot(x=attacks_per_year.index, y=attacks_per_year.values)
plt.title('Número de ataques de tiburones por año (Desde 1700)')
plt.xlabel('Año')
plt.ylabel('Número de ataques')
plt.show()

# %%
print(attacks_per_year)
# Out:
# Year
# 1700.0      3
# 1703.0      1
# 1721.0      1
# 1733.0      1
# 1738.0      1
#          ...
# 2013.0    122
# 2014.0    126
# 2015.0    141
# 2016.0    128
# 2017.0     54
# Length: 227, dtype: int64

# %% [markdown]
# Aca vemos que los ataques aumentan a medida que estamos mas cercanos a la actualidad. Esto podria llegar a ser por una cuestion de que hay mejores formas de registrar los casos. Ademas, el dataset supuestamente era de los "ultimos 100 años", pero al parecer desde el 1850 en adelante vemos un incremento en los casos. Ademas, vemos que en 2017 es el ultimo año y hubo menos casos, los dejaron de actualizar hace 5 años segun la pagina.

# %%
n = 10
country_counts = df2['Country'].value_counts().nlargest(n)  #seleccionar los paises con mas ataques porque sino quedaba muy grande
plt.figure(figsize=(10,6))
plt.bar(country_counts.index, country_counts.values)
plt.title(f'Número de ataques de tiburones por país (Top {n})')
plt.xlabel('País')
plt.ylabel('Número de ataques')
plt.xticks(rotation=45)  ##rotar
plt.show()

# %% [markdown]
# este grafico es bastante claro, si bien solo tiene los 10 paises con mas ataques. habria que indagar si es por una cuestion de que USA contabiliza mejor los casos por alguna cuestion, si los otros paises no son tan rigurosos, o la poblacion de tiburones en cada pais, que tambien puede ser lo que genere la diferencia tan amplia.

# %%
fatal_counts = df2['Fatal (Y/N)'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(fatal_counts.values, autopct='%1.1f%%') #el autopct es para que muestre los %
plt.title('Porcentaje de ataques mortales y no mortales')
plt.legend(labels=fatal_counts.index, loc='upper right')
plt.show()

##aca me gustaria convertir todo para que solo sea N o Y

# %% [markdown]
# esto es bastante claro, vemos que 73% de los ataques (faltaria limpiar un poco los datos, unir todos los N y los Y, y sacar 2017 y #VALUE!) son no mortales. Esto es algo muy util para saber, ya que mucha gente le tiene terror a que lo ataque un tiburon, y ya de base es poco probable, y dentro de la poca probabilidad (pocos casos en los utlimos años), es poco probable que sea mortal. Sin embargo, no debe ser lindo ser atacado por un tiburon, por lo que tenemos que ver cuestiones para prevenir ataques.

# %%
df2['Age'] = pd.to_numeric(df2['Age'], errors='coerce')

sns.violinplot(x=df2['Age'])
plt.title('Distribución de la edad de las víctimas de ataques de tiburones')

##rarisimo grafico, tendria que ver como hacer para que sea mas claro
# Out:
# <ipython-input-19-efba5eb6c9f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Age'] = pd.to_numeric(df2['Age'], errors='coerce')
# Text(0.5, 1.0, 'Distribución de la edad de las víctimas de ataques de tiburones')

# %% [markdown]
# creo que este grafico de violin aca no es tan util ya que no tenemos tantas categorias para analizar, entiendo que vemos la distribución de los datos y su densidad, pero nos confirma lo que ya vimos previamente, que la mayoria de las victimas estan alrededor de los 20 años.

# %%
activity_counts = df2['Activity'].value_counts().nlargest(10)  ##10 actividades mas grandes
sns.barplot(x=activity_counts.index, y=activity_counts.values)
plt.title('Número de ataques de tiburones por actividad')
plt.xlabel('Actividad')
plt.ylabel('Número de ataques')
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# Este grafico es muy interesante, ya que podemos ver que la mayoria de los casos ocurren surfeando o nadando. De esta forma, se puede trabajar sobre medidas de proteccion al momento de realizar estas actividades. Es interesante ver que, por ejemplo. "standing", que supongo que sera estar parados en la playa, tiene mas casos que "scuba diving", que implica estar literalmente abajo del agua. Esto nos podria dar indicios del comportamiento de los tiburones.

# %% [markdown]
# # American Citizens Annual Salary Dataset

# %% [markdown]
# ## Introducción, Variables y Posibilidades

# %%
from IPython.display import Image

Image("/content/drive/MyDrive/Data Science CoderHouse/Datasets + IMG + Docu/dataset-cover.jpg")

# %% [markdown]
# El dataset contiene información sobre la demografía, educación, experiencia laboral y otros factores relevantes de las personas. Luego, la columna de ingresos en el dataset (la mas importante), se utiliza como variable objetivo, categorizada en dos clases: "<=50K" (indicando ingresos menores o iguales a 50,000) y ">50K" (para ingresos mayores a 50,000).
#
# A través de la exploración de variables demográficas, educativas, laborales, se podría construir un modelo que pueda clasificar a los individuos en dos categorías: ingresos menores o iguales a $50,000 y ingresos superiores a esa cantidad. Este modelo tiene diversas aplicaciones, como el análisis de ingresos, ver si es posible la segmentación, si hay algun tipo de correlacion entre las variables y los ingresos, entre otras posibilidaes.
#
# --------------------------------------------------------------------------------
# A continuacion, cada titulo de columna y una breve descripcion realizada por el que subio el dataset a Kaggle (https://www.kaggle.com/datasets/amirhosseinmirzaie/americancitizenincome?resource=download)
#
# age: Edad.
#
# workclass: Término general que indica el estado laboral de un individuo.
#
# fnlwgt: Peso final, que representa el número de individuos que esta fila representa (una muestra representativa).
#
# education: Nivel educativo más alto alcanzado por un individuo.
#
# education.num: Nivel educativo más alto alcanzado por un individuo en forma numérica.
#
# marital.status: Estado civil de un individuo. Nota que "Married-civ-spouse" se refiere a un cónyuge civil, y "Married-AF-spouse" se refiere a un cónyuge en las Fuerzas Armadas.
#
# occupation: Tipo general de ocupación de un individuo.
#
# relationship: Relación de este individuo con otros, por ejemplo, cónyuge (Esposo). Cada punto de datos tiene solo una relación.
#
# race: Raza.
#
# sex: Sexo biológico de un individuo.
#
# capital.gain: Ganancias de capital de un individuo.
#
# capital.loss: Pérdidas de capital de un individuo.
#
# hours.per.week: Número de horas que el individuo reportó trabajar por semana.
#
# native.country: País de origen.
#
# income: Ingresos, menos o iguales a $50,000 (<=50K) o más que eso (>50K).

# %%
pathac = "/content/drive/MyDrive/Data Science CoderHouse/Datasets + IMG + Docu/American Citizens Annual Income.csv"
dfac = pd.read_csv(pathac, encoding='latin1')
dfac
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       40  Self-emp-not-inc  223881   Prof-school             15
# 1       30           Private  149118       HS-grad              9
# 2       46           Private  109209  Some-college             10
# 3       32           Private  229566     Assoc-voc             11
# 4       54                 ?  148657     Preschool              1
# ...    ...               ...     ...           ...            ...
# 24995   40           Private  130834  Some-college             10
# 24996   31         Local-gov   33124     Bachelors             13
# 24997   38       Federal-gov  190895     Bachelors             13
# 24998   23           Private  420973     Bachelors             13
# 24999   60           Private   88055          10th              6
#
#            marital.status        occupation   relationship   race     sex  \
# 0      Married-civ-spouse    Prof-specialty        Husband  White    Male
# ...

# %%
dfac.shape
# Out:
# (25000, 15)

# %%
print(f'Cantidad de Registros: {dfac.shape[0]}')
print(f'Cantidad de Columnas: {dfac.shape[1]}')
# Out:
# Cantidad de Registros: 25000
# Cantidad de Columnas: 15

# %%
#Listado de Columnas
dfac.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
dfac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             25000 non-null  int64
#  1   workclass       25000 non-null  object
#  2   fnlwgt          25000 non-null  int64
#  3   education       25000 non-null  object
#  4   education.num   25000 non-null  int64
#  5   marital.status  25000 non-null  object
#  6   occupation      25000 non-null  object
#  7   relationship    25000 non-null  object
#  8   race            25000 non-null  object
#  9   sex             25000 non-null  object
#  10  capital.gain    25000 non-null  int64
#  11  capital.loss    25000 non-null  int64
#  12  hours.per.week  25000 non-null  int64
#  13  native.country  25000 non-null  object
#  14  income          25000 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 2.9+ MB

# %%
dfac.head().T
# Out:
#                                  0              1                   2  \
# age                             40             30                  46
# workclass         Self-emp-not-inc        Private             Private
# fnlwgt                      223881         149118              109209
# education              Prof-school        HS-grad        Some-college
# education.num                   15              9                  10
# marital.status  Married-civ-spouse       Divorced  Married-civ-spouse
# occupation          Prof-specialty   Craft-repair        Adm-clerical
# relationship               Husband  Not-in-family             Husband
# race                         White          White               White
# sex                           Male         Female                Male
# capital.gain                 99999              0                   0
# capital.loss                     0              0                   0
# ...

# %%
plt.hist(dfac['age'], bins=20, width=3)
plt.title('Distribución de la Edad')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
##los niveles de educacion de eeuu me parecne medio confusos, podria agruparlos de otra forma despues
education_counts = dfac['education'].value_counts()
education_counts.plot(kind='bar')
plt.title('Distribución de la Educación')
plt.xlabel('Educación')
plt.ylabel('Frecuencia')
plt.xticks(rotation=55)
plt.show()

# %%
plt.hist(dfac['hours.per.week'], bins=20, width=4)
plt.title('Distribución de Horas por Semana')
plt.xlabel('Horas por Semana')
plt.ylabel('Frecuencia')
plt.show()

# %%
sns.histplot(data=dfac, x='age', bins=20, kde=True)
plt.title('Distribución de la Edad')
plt.show()

# %%
sns.countplot(data=dfac, x='sex')
plt.title('Distribución de Sexo')
plt.show()

# %%
sns.boxplot(data=dfac, x='income', y='hours.per.week')
plt.title('Horas por Semana según los Ingresos')
plt.show()

#medio raro pero esta bueno, igual la mayoria entre 40 y 50

# %% [markdown]
# #Hechos y víctimas de muertes viales en la República Argentina Dataset

# %% [markdown]
# ## Introducción, Variables y Posibilidades

# %%
from IPython.display import Image

Image("/content/drive/MyDrive/Data Science CoderHouse/Datasets + IMG + Docu/ruta argentina.jpeg")

# %% [markdown]
# Este dataset es una base de microdatos sobre hechos y víctimas de muertes viales en la República Argentina, entre 2017 y 2020 provenientes del Sistema Nacional de Información Criminal.
#
# Gracias a los datos provistos, se puede realizar un análisis de los lugares de accidentes, para identificar áreas de riesgo. También es posible analizar patrones temporales, evaluar factores contribuyentes, comprender las características demográficas de las víctimas y evaluar el impacto de los vehículos. Este dataset, y el posterior analisis, permite comprender y abordar los desafíos de seguridad vial en Argentina, a fin de elaborar respuestas a ciertos patrones que podrian (o no) encontrarse.
#
# --------------------------------------------------------------------------------
#
# A continuacion, cada titulo de columna y una breve descripcion realizada por el
# Ministerio de Seguridad de la Nación. Unidad de Gabinete de Asesores. Dirección Nacional de Estadística Criminal. (https://datos.gob.ar/ko_KR/dataset/seguridad-estadisticas-criminales-republica-argentina-sistema-alerta-temprana-muertes-viales/archivo/seguridad_10.1)
#
# Id_hecho: Número entero que representa el código de identificación del hecho.
#
# tipo_fuerza: Texto que indica el tipo de fuerza de seguridad responsable del reporte del hecho.
#
# federal: Texto que indica si el dato es reportado por alguna fuerza federal.
#
# Cod_INDEC_Prov: Texto que representa el código de la provincia donde ocurrió el hecho según el Instituto Nacional de Estadística y Censo (INDEC).
#
# provincia: Texto que indica el nombre de la provincia donde ocurrió el hecho.
#
# codigo_departamento: Texto que representa el código identificador del departamento de ocurrencia del hecho.
#
# Cod_INDEC: Texto que indica el código identificador de 5 cifras para el departamento y la provincia.
#
# departamento: Texto que indica el nombre del departamento geográfico donde ocurrió el hecho.
#
# localidad: Texto que indica el nombre de la localidad donde ocurrió el hecho.
# codigo_localidad: Texto que representa el código de la localidad donde ocurrió el hecho según el Instituto Nacional de Estadística y Censo (INDEC).
#
# anio: Fecha en formato ISO-8601 que indica el año de ocurrencia del hecho.
#
# mes: Fecha en formato ISO-8601 que indica el mes de ocurrencia del hecho.
#
# fecha_hecho: Fecha en formato ISO-8601 que indica la fecha del hecho.
#
# hora_hecho: Fecha en formato ISO-8601 que indica la hora del hecho.
#
# calle: Texto que indica el nombre de la calle o ruta donde sucedió el hecho.
#
# altura: Número decimal que indica la altura de la calle o kilómetro de la ruta en la que ocurrió el hecho.
#
# interseccion: Texto que determina si el hecho ocurrió en una intersección de calles.
#
# calle_interseccion: Texto que indica la calle de intersección en la que ocurrió el hecho (que corta perpendicularmente a la registrada en la variable Calle).
#
# estado_semaforo: Texto que registra el estado del funcionamiento del semáforo en el momento y el lugar en que aconteció el hecho.
#
# tipo_lugar: Texto que indica el tipo de lugar en el que aconteció el hecho.
#
# modo_produccion_hecho: Texto que registra el modo o la modalidad en la cual se produjo el hecho.
#
# modo_produccion_hecho_ampliada: Texto que indica el modo de producción del hecho con mayor cantidad de tipologías.
#
# otro_modo_hecho: Texto que especifica el modo en el cual se produjo el hecho en caso de no estar incluido en las categorías predeterminadas.
#
# condicion_clima: Texto que registra las condiciones climáticas presentes en el momento y el lugar del hecho.
#
# otro_clima: Texto que especifica las condiciones climáticas presentes en el momento y lugar del hecho en caso de no estar incluido en las categorías predeterminadas.
#
# motivo_origen_registro: Texto que registra el motivo que origina el registro del hecho.
#
# otro_motivo_origen_registro: Texto que especifica el motivo que origina el registro del hecho en caso de no estar incluido en las categorías predeterminadas.
#
# tipo_persona: Texto que caracteriza el tipo de persona: víctima o inculpado.
#
# tipo_persona_id: Texto que representa el código identificador de la persona involucrada en el hecho.
#
# sexo_victima: Texto que indica el sexo de la víctima del hecho.
#
# tr_edad_victima: Texto que indica la edad de la víctima en tramos.
#
# clase_victima: Texto que indica la clase de la víctima del hecho.
#
# otro_clase_victima: Texto que especifica la clase de víctima en caso de no estar incluido en las categorías predeterminadas de la variable Clase víctima.
#
# vehiculo_victima: Texto que registra el tipo de vehículo de la víctima del hecho.
#
# vehiculo_victima_ampliado: Texto que indica el tipo de vehículo de la víctima con mayor cantidad de categorías.
#
# otro_vehiculo_victima: Texto que especifica el tipo de vehículo de la víctima del hecho en caso de no estar incluido en las categorías predeterminadas de la variable Vehículo víctima.
#
# sexo_inculpado: Texto que indica el sexo del inculpado del hecho.
#
# tr_edad_inculpado: Texto que indica la edad de la persona involucrada en el siniestro en tramos.
#
# vehiculo_inculpado: Texto que registra el tipo de vehículo del inculpado del hecho.
#
# vehiculo_inculpado_ampliado: Texto que indica el tipo de vehículo del inculpado con más detalle de categorías.
#
# otro_vehiculo_inculpado: Texto que especifica el tipo de vehículo del inculpado del hecho en caso de no estar incluido en las categorías predeterminadas de la variable Vehículo inculpado.

# %%
pathvs = "/content/drive/MyDrive/Data Science CoderHouse/Datasets + IMG + Docu/Victimas siniestros argentina.xlsx"
dfvs = pd.read_excel(pathvs)
dfvs
# Out:
#        Id_hecho        tipo_fuerza federal  Cod_INDEC_Prov     provincia  \
# 0         13075  Fuerza Provincial      No              58       NEUQUEN
# 1         13075  Fuerza Provincial      No              58       NEUQUEN
# 2         13076  Fuerza Provincial      No              58       NEUQUEN
# 3         13076  Fuerza Provincial      No              58       NEUQUEN
# 4         13076  Fuerza Provincial      No              58       NEUQUEN
# ...         ...                ...     ...             ...           ...
# 30541     34506  Fuerza Provincial      No               6  BUENOS AIRES
# 30542     34507  Fuerza Provincial      No               6  BUENOS AIRES
# 30543     34507  Fuerza Provincial      No               6  BUENOS AIRES
# 30544     34508  Fuerza Provincial      No               6  BUENOS AIRES
# 30545     34508  Fuerza Provincial      No               6  BUENOS AIRES
#
#       codigo_departamento  Cod_INDEC     departamento        localidad  \
# ...

# %%
dfvs.shape
# Out:
# (30546, 41)

# %%
print(f'Cantidad de Registros: {dfvs.shape[0]}')
print(f'Cantidad de Columnas: {dfvs.shape[1]}')
# Out:
# Cantidad de Registros: 30546
# Cantidad de Columnas: 41

# %%
#Listado de Columnas
dfvs.columns
# Out:
# Index(['Id_hecho', 'tipo_fuerza', 'federal', 'Cod_INDEC_Prov', 'provincia',
#        'codigo_departamento', 'Cod_INDEC', 'departamento', 'localidad',
#        'codigo_localidad', 'anio', 'mes', 'fecha_hecho', 'hora_hecho', 'calle',
#        'altura', 'interseccion', 'calle_interseccion', 'estado_semaforo',
#        'tipo_lugar', 'modo_produccion_hecho', 'modo_produccion_hecho_ampliada',
#        'otro_modo_hecho', 'condicion_clima', 'otro_clima',
#        'motivo_origen_registro', 'otro_motivo_origen_registro', 'tipo_persona',
#        'tipo_persona_id', 'sexo_victima', 'tr_edad_victima', 'clase_victima',
#        'otro_clase_victima', 'vehiculo_victima', 'vehiculo_victima_ampliado',
#        'otro_vehiculo_victima', 'sexo_inculpado', 'tr_edad_inculpado',
#        'vehiculo_inculpado', 'vehiculo_inculpado_ampliado',
#        'otro_vehiculo_inculpado'],
#       dtype='object')

# %%
dfvs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30546 entries, 0 to 30545
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Id_hecho                        30546 non-null  int64
#  1   tipo_fuerza                     30546 non-null  object
#  2   federal                         30546 non-null  object
#  3   Cod_INDEC_Prov                  30546 non-null  int64
#  4   provincia                       30546 non-null  object
#  5   codigo_departamento             30546 non-null  object
#  6   Cod_INDEC                       30546 non-null  int64
#  7   departamento                    30546 non-null  object
#  8   localidad                       30546 non-null  object
#  9   codigo_localidad                30546 non-null  object
#  10  anio                            30546 non-null  int64
#  11  mes                             30546 non-null  int64
# ...

# %%
dfvs.head().T
# Out:
#                                                            0  \
# Id_hecho                                               13075
# tipo_fuerza                                Fuerza Provincial
# federal                                                   No
# Cod_INDEC_Prov                                            58
# provincia                                            NEUQUEN
# codigo_departamento                                       35
# Cod_INDEC                                              58035
# departamento                                     Confluencia
# localidad                                            Neuquén
# codigo_localidad                                          70
# anio                                                    2017
# mes                                                        1
# fecha_hecho                              2017-01-05 00:00:00
# hora_hecho                                          08:30:00
# ...

# %%
provincia_counts = dfvs['provincia'].value_counts()
provincia_counts.plot(kind='bar', edgecolor='black')
plt.title('Accidentes por Provincia')
plt.xlabel('Provincia')
plt.ylabel('Frecuencia')
plt.show()

# %%
dfvs['hora'] = pd.to_datetime(dfvs['hora_hecho']).dt.hour
plt.hist(dfvs['hora'], bins=24, width=0.8)
plt.title('Distribución de Accidentes por Hora del Día')
plt.xlabel('Hora del Día')
plt.ylabel('Frecuencia')
plt.show()

# %%
sns.countplot(data=dfvs, x='sexo_victima')
plt.title('Accidentes por Sexo de la Víctima')
plt.show()

## porque hay tantos no corresponde??

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=dfvs, y='vehiculo_victima')
plt.title('Accidentes por Tipo de Vehículo de la Víctima')
plt.show()

## no corresponde?

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=dfvs, y='tipo_lugar', order=dfvs['tipo_lugar'].value_counts().index)
plt.title('Cantidad de Accidentes por Tipo de Lugar')
plt.show()
